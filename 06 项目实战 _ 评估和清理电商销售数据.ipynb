# %% [markdown]
# # 项目：评估和清理英国电商公司销售数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，根据市场销售数据，挖掘畅销产品，以便制定更有效的市场策略来提升营收。
#
# 本实战项目的目的在于练习评估数据干净和整洁度，并且基于评估结果，对数据进行清洗，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了一家英国在线零售公司在2010年12月1日至2011年12月9日期间的所有交易情况，涵盖了该公司在全球不同国家和地区的业务数据。该公司主要销售覆盖各个场景的礼品，包括但不限于生日礼品、结婚纪念品、圣诞礼品等等。该公司的客户群体主要包括批发商和个人消费者，其中批发商占据了相当大的比例。

# %% [markdown]
# 数据每列的含义如下：
# - `InvoiceNo`: 发票号码。6位数，作为交易的唯一标识符。如果这个代码以字母“c”开头，表示这笔交易被取消。
# - `StockCode`: 产品代码。5位数，作为产品的唯一标识符。
# - `Description`: 产品名称。
# - `Quantity`: 产品在交易中的数量。
# - `InvoiceDate`: 发票日期和时间。交易发生的日期和时间。
# - `UnitPrice`: 单价。价格单位为英镑（£）。
# - `CustomerID`: 客户编号。5位数，作为客户的唯一标识符。
# - `Country`: 国家名称。客户所居住的国家的名称。

# %% [markdown]
# ## 读取数据

# %%
import pandas as pd

# %%
original_data = pd.read_csv("D:\\ai(li)data course\\04.数据评估与清洗篇\\数据清洗评估实战\\e_commerce.csv")

# %%
original_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## 评估数据

# %% [markdown]
# ##### 这一步的作用为：随机查看几列数据，通过随机取样查看数据整体结构是否符合数据规范，

# %%
original_data.sample(10)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 293676    562610     21915             RED  HARMONICA IN BOX        700
# 220671    556206        C2                           CARRIAGE         1
# 270221    560552     23033            DRAWER KNOB CERAMIC RED        96
# 430018    573579     22899       CHILDREN'S APRON DOLLY GIRL          1
# 406481    571797     22089      PAPER BUNTING VINTAGE PAISLEY         1
# 344873    567124     21669    BLUE STRIPE CERAMIC DRAWER KNOB        36
# 248417    558814     23207          LUNCH BAG ALPHABET DESIGN        10
# 448777    575070     22352  LUNCH BOX WITH CUTLERY RETROSPOT          1
# 242577    558358     22197                     POPCORN HOLDER        14
# 42477     539991     72741              GRAND CHOCOLATECANDLE         4
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 293676    8/8/2011 11:56       1.06     16333.0  United Kingdom
# ...

# %% [markdown]
# ##### 数据结构符合每行为观察值（个体），每列为属性的数据规范。

# %% [markdown]
# ### 评估数据干净程度

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ##### 根据该段数据，可看出Description，CustomerID数据条数低于总条数，因此这两条数据有缺失数据；此外InvoiceDate数据类型应该是数字，但在表中是字符串；而CustomerID应该是字符串。

# %% [markdown]
# #### 评估缺失数据

# %% [markdown]
# #### 在了解Description存在缺失值后，筛选出缺失观察值

# %%
original_data[original_data["Description"].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/2010 14:34        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535322    581199     84581         NaN        -2  12/7/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/2011 14:06        0.0
#
#         CustomerID         Country
# ...

# %% [markdown]
# #### 筛选是否具有UnitPrice有效但Description缺失的数据

# %%
original_data[(original_data["Description"].isnull()) & (original_data["UnitPrice"] != 0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# ##### 结果显示，Description缺失的数据价格信息也缺失，不符合筛选“畅销产品”的分析目的，因此这些缺失值都属于无效数据，可以进行删除。

# %% [markdown]
# #### 对同样缺失的CustomerID数据进行同样操作

# %%
original_data[original_data["CustomerID"].isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/1/2010 11:52       0.00         NaN  United Kingdom
# ...

# %% [markdown]
# ##### 因为CustomerID不是分析畅销产品的必要变量，缺失CustomerID的部分关键变量，即UnitPrice和Description皆无缺失关联，因此对于CustomerID缺失的数据不需予以处理。

# %% [markdown]
# #### 评估重复数据

# %% [markdown]
# ##### 根据数据描述可知，虽然InvoiceNo，StockCode，CustomerID三个变量都是唯一标识符，但同一次交易可以包含多件商品，因此InvoiceNo可以重复出现；同一商品可以交易多次，因此StockCode可重复出现；同一用户也可多次交易，因此CustomerID可重复出现。

# %% [markdown]
# #### 评估不一致数据

# %% [markdown]
# ##### 不一致数据可能存在于“country”变量中，我们要查看是否存在多个不同值指代同一国家的情况。

# %%
original_data['Country'].value_counts()
# Out:
# Country
# United Kingdom          495266
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# China                      288
# Singapore                  229
# USA                        218
# UK                         211
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# ...

# %% [markdown]
# ##### 从Country变量值可看出，“United Kingdom”，“UK”，“U.K.”都代表英国，而“USA”，“United States”都代表美国，因此在清洗阶段需要对它们进行统一。
